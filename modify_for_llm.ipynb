# %%
import pickle
import json
import numpy as np
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
with open("llama_answers.pkl", 'rb') as f:
    llama_answers = pickle.load(f)
    f.close()

with open("claude_answers.pkl", "rb") as f:
    claude_answers = pickle.load(f)
    f.close()

with open("compare_llama.pkl", "rb") as f:
    compare_llama = pickle.load(f)
    f.close()

with open("compare_claude.pkl", "rb") as f:
    compare_claude = pickle.load(f)
    f.close()

# %%
LLAMA_API = "https://stock.cmcts.ai/c-agent/api/v1/prediction/dd0f9487-4ab8-4dc6-8b16-b665e3121499"
CLAUDE_API = "https://stock.cmcts.ai/c-agent/api/v1/prediction/bb99269d-6f89-414e-8702-5d84c5f8e1a4"
GRADER_API = "https://stock.cmcts.ai/c-agent/api/v1/prediction/d6675cbc-88a6-4ca4-8f1a-cf660a60beb8"

# %%
from langfuse import Langfuse
langfuse = Langfuse(public_key="pk-lf-9c1bbc22-8180-4c1e-9d1c-4bedf12c56fc",
                    secret_key="sk-lf-d758beb3-be26-4e22-9f7b-847bd9142d2b",
                    host="https://us.cloud.langfuse.com",)

current_id  = langfuse.fetch_traces(limit=1).data[0].id
current_id
# Out:
# 'f050e3cf-123d-48c4-9855-2e664d5e5550'

# %%
def query(payload, api):
    response = requests.post(api, json=payload)
    return response

# %%
def get_answers(questions, api, llm_node):
    global current_id
    answers = [] 
    for question in questions:
        payload = {"question": question}
        temp = query(payload, api)
        while True:
            data = langfuse.fetch_traces(limit=1).data[0]
            if current_id != data.id and (data.output is not None and not isinstance(data.output, str)):
                answers.append(data.output[llm_node]["messages"][0]["kwargs"]["content"])
                current_id = data.id
                print("Checkpoint: Got answer!")
                break
    return answers

# %%
def get_comparisons(questions, ground_truth_answers, llm_answers):
    global current_id
    comparisons = []
    for question, groundTruthAnswer, llmAnswer in zip(questions, ground_truth_answers, llm_answers):
        compare_question = f"""
        Question: {question}\n\n
        Ground-truth answer: {groundTruthAnswer}\n\n
        LLM answer: {llmAnswer}
        """
        payload = {"question": compare_question}
        temp = query(payload, GRADER_API)

        while True:
            data = langfuse.fetch_traces(limit=1).data[0]
            if current_id != data.id and (data.output is not None and not isinstance(data.output, str)):
                comparisons.append(data.output["tax_grader"]["messages"][0]["kwargs"]["content"])
                current_id = data.id
                print("Checkpoint: Got comparison")
                break
    return comparisons

# %%
def insert_subcol(score_df_data, comment_df_data, subcol, answers, data):
    new_score_df_data = {}
    for (top_level, sub_level), value in score_df_data.items():
        new_score_df_data[(top_level, sub_level)] = value
        if top_level == "Generation" and sub_level == "Llama":
            new_score_df_data[("Generation", subcol)] = data["generation_score"]
        
        if top_level == "Sources - Laws" and sub_level == "Llama":
            new_score_df_data[("Sources - Laws", subcol)] = data["sources_laws_score"]

        if top_level == "Brevity" and sub_level == "Llama":
            new_score_df_data[("Brevity", subcol)] = data["brevity_score"]

        if top_level == "Average score" and sub_level == "Llama":
            new_score_df_data[("Average score", subcol)] = data["average_score"]

    # Comment df
    new_comment_df_data = {}
    for (top_level, sub_level), value in comment_df_data.items():
        new_comment_df_data[(top_level, sub_level)] = value
        if top_level == "LLM anwser" and sub_level == "Llama":
            new_comment_df_data[("LLM anwser", subcol)] = answers
        if top_level == "Đánh giá" and sub_level == "Llama":
            new_comment_df_data[("Đánh giá", subcol)] = data["comment"]

    return new_score_df_data, new_comment_df_data

# %%
qa_df = pd.read_csv("data/tax_qa.csv")
qa_df.head()
# Out:
#                                              Câu hỏi  \
# 0  Người lao động ký hợp đồng lao động không thời...
# 1  Mẫu biểu quyết toán thuế TNCN của cty là mẫu n...
# 2  "Bên em có trường hợp xuất Chứng từ khấu trừ t...
# 3  NLĐ vừa có thời gian thử việc khấu trừ thuế TN...
# 4  Quyết toán thuế TNCN đối với cá nhân được điều...
#
#                              Câu trả lời sau rà soát
# 0  'Căn cứ Điểm b.2 Khoản 1 Điều 25 Thông tư 111/...
# 1  Tại  điểm b tiết 9.9 Khoản 9 Phụ lục I ban hàn...
# 2  Đối với vướng mắc của Công ty về mẫu biểu tờ k...
# 3  - Điều 25 Thông tư số 111/2013/TT-BTC quy định...
# 4  Trường hợp cá nhân điều chuyển từ tổ chức cũ s...

# %%
questions = qa_df["Câu hỏi"].values
groundTruthAnswers = qa_df["Câu trả lời sau rà soát"].values

# %%
score_df = pd.read_excel("data/comparisons_v2.xlsx", sheet_name="Điểm", header=[0,1])
comment_df = pd.read_excel("data/comparisons_v2.xlsx", sheet_name="Đánh giá", header=[0,1])

# %% [markdown]
# ### Claude sonnet 3.7

# %%
claude_sonnet_3_7_answers = get_answers(questions, CLAUDE_API, llm_node="tax_claude")
# Out:
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!
# Checkpoint: Got answer!

# %%
# Claude
claude_3_7_compare = get_comparisons(questions=questions, ground_truth_answers=groundTruthAnswers, llm_answers=claude_sonnet_3_7_answers)
# Out:
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison
# Checkpoint: Got comparison

# %%
average_score = 0
for compare in claude_3_7_compare:
    compare = json.loads(compare)
    generation_score = float(compare["generation_score"])
    sources_laws_score = float(compare["sources_laws_score"])
    brevity_score = float(compare["brevity_score"])
    average_score_per_cirtical = np.round((generation_score + sources_laws_score + brevity_score)/3, 2)
    average_score += average_score_per_cirtical
    print(generation_score, sources_laws_score, brevity_score, average_score_per_cirtical)
print(np.round(average_score/10, 2))
# Out:
# 8.0 6.0 7.0 7.0
# 5.0 4.0 6.0 5.0
# 8.0 7.0 9.0 8.0
# 6.0 5.0 7.0 6.0
# 3.0 2.0 3.0 2.67
# 6.0 4.0 7.0 5.67
# 3.0 4.0 6.0 4.33
# 9.0 8.0 9.0 8.67
# 7.0 6.0 6.0 6.33
# 9.0 8.0 8.0 8.33
# 6.2

# %%
data = {"Question": [],
        "Ground-truth answer": [],
        "LLM answer": [],
        "Generation": [],
        "Generation score": [],
        "Sources - Laws": [],
        "Sources - Laws score": [],
        "Brevity": [],
        "Brevity score": [],
        "Comment": [],
        "Average score": [],
        "Strength Weakness": []}

for question, ground_truth_answer, llm_answer, comparison in zip(questions, groundTruthAnswers, claude_sonnet_3_7_answers, claude_3_7_compare):
    compare = json.loads(comparison)
    data["Question"].append(question)
    data["Ground-truth answer"].append(ground_truth_answer)
    data["LLM answer"].append(llm_answer)
    data["Generation"].append(compare["generation"])
    data["Sources - Laws"].append(compare["sources_laws"])
    data["Brevity"].append(compare["brevity"])
    data["Generation score"].append(float(compare["generation_score"]))
    data["Sources - Laws score"].append(float(compare["sources_laws_score"]))
    data["Brevity score"].append(float(compare["brevity_score"]))
    data["Comment"].append(compare["comment"])
    data["Average score"].append(np.round((data["Generation score"][-1]\
                                 + data["Sources - Laws score"][-1]\
                                 + data["Brevity score"][-1])/3, 2))
    data["Strength Weakness"].append(compare["strength_weakness"])

# %%
temp_df = pd.DataFrame(data)
temp_df
# Out:
#                                             Question  \
# 0  Người lao động ký hợp đồng lao động không thời...
# 1  Mẫu biểu quyết toán thuế TNCN của cty là mẫu n...
# 2  "Bên em có trường hợp xuất Chứng từ khấu trừ t...
# 3  NLĐ vừa có thời gian thử việc khấu trừ thuế TN...
# 4  Quyết toán thuế TNCN đối với cá nhân được điều...
# 5  Cá nhân trong năm vừa có thu nhập tính thuế th...
# 6  Mẫu số 02/QTT-TNCN/ TT80, trong trường hợp quy...
# 7  Tôi đang kê khai quyết toán thuế nhưng phần kê...
# 8  A/C cho e hỏi có bắt buộc phải điền mã số thuế...
# 9  Trong năm 2023 tôi có làm việc tại Nha Trang, ...
#
#                                  Ground-truth answer  \
# 0  'Căn cứ Điểm b.2 Khoản 1 Điều 25 Thông tư 111/...
# 1  Tại  điểm b tiết 9.9 Khoản 9 Phụ lục I ban hàn...
# 2  Đối với vướng mắc của Công ty về mẫu biểu tờ k...
# 3  - Điều 25 Thông tư số 111/2013/TT-BTC quy định...
# 4  Trường hợp cá nhân điều chuyển từ tổ chức cũ s...
# 5  Căn cứ điểm d Khoản 6 Điều 8 Nghị định 126/202...
# 6  Người nộp thuế kê khai chỉ tiêu số thuế TNCN đ...
# 7  Để khắc phục lỗi kê khai bảng kê (05-1/BK-TNCN...
# 8  Đơn vị chi trả thu nhập có trách nhiệm thực hi...
# 9  Căn cứ điểm b khoản 8 Điều 11 Nghị định số 126...
#
#                                           LLM answer  \
# 0  Đối với trường hợp người lao động ký hợp đồng ...
# 1  Theo quy định hiện hành, các mẫu biểu liên qua...
# 2  Xin chào bạn,\n\nĐối với trường hợp xuất Chứng...
# 3  Đối với trường hợp người lao động vừa có thời ...
# 4  Đối với cá nhân được điều chuyển từ tổ chức cũ...
# 5  Theo quy định hiện hành, cá nhân có đồng thời ...
# 6  Theo quy định tại Thông tư số 80/2021/TT-BTC n...
# 7  Để khắc phục lỗi kê khai bảng kê (05-1/BK-TNCN...
# 8  Theo quy định hiện hành, việc điền mã số thuế ...
# 9  Theo quy định tại điểm b Khoản 8 Điều 11 Nghị ...
#
#                                           Generation  Generation score  \
# 0  Câu trả lời của mô hình LLM có độ chính xác kh...               8.0
# 1  Câu trả lời của mô hình LLM có một số điểm chí...               5.0
# 2  Câu trả lời của mô hình LLM có độ chính xác kh...               8.0
# 3  Câu trả lời của mô hình LLM không hoàn toàn ch...               6.0
# 4  Câu trả lời của mô hình LLM có một số điểm khô...               3.0
# 5  Câu trả lời của mô hình LLM có một số điểm chí...               6.0
# 6  Câu trả lời của mô hình LLM không chính xác so...               3.0
# 7  Câu trả lời của mô hình LLM đã cung cấp thông ...               9.0
# 8  Câu trả lời của mô hình LLM có độ chính xác kh...               7.0
# 9  Câu trả lời của mô hình LLM về cơ bản là chính...               9.0
#
#                                       Sources - Laws  Sources - Laws score  \
# 0  Mô hình LLM đã trích dẫn một số văn bản pháp l...                   6.0
# 1  Câu trả lời của mô hình LLM có đề cập đến một ...                   4.0
# 2  Mô hình LLM đã trích dẫn một số văn bản pháp l...                   7.0
# 3  Mô hình có trích dẫn Thông tư số 80/2021/TT-BT...                   5.0
# 4  Mô hình LLM đã trích dẫn Thông tư số 80/2021/T...                   2.0
# 5  Mô hình LLM đã cố gắng trích dẫn nguồn luật, n...                   4.0
# 6  Mô hình có đề cập đến Thông tư số 80/2021/TT-B...                   4.0
# 7  Câu trả lời của mô hình không trích dẫn cụ thể...                   8.0
# 8  Mô hình LLM đã trích dẫn một số văn bản pháp l...                   6.0
# 9  Mô hình đã trích dẫn chính xác nguồn luật là đ...                   8.0
#
#                                              Brevity  Brevity score  \
# 0  Câu trả lời của mô hình LLM dài hơn so với câu...            7.0
# 1  Câu trả lời của mô hình LLM tương đối ngắn gọn...            6.0
# 2  Câu trả lời của mô hình LLM có độ ngắn gọn và ...            9.0
# 3  Câu trả lời của mô hình khá ngắn gọn và súc tí...            7.0
# 4  Câu trả lời của mô hình LLM dài hơn nhiều so v...            3.0
# 5  Câu trả lời của mô hình LLM có độ dài tương đố...            7.0
# 6  Câu trả lời của mô hình khá ngắn gọn, nhưng do...            6.0
# 7  Câu trả lời của mô hình LLM truyền tải đầy đủ ...            9.0
# 8  Câu trả lời của mô hình LLM dài hơn so với câu...            6.0
# 9  Câu trả lời của mô hình LLM có độ dài phù hợp,...            8.0
#
#                                              Comment  Average score  \
# 0  Câu trả lời của mô hình LLM có độ chính xác tư...           7.00
# 1  Đánh giá tổng thể, câu trả lời của mô hình LLM...           5.00
# 2  Nhìn chung, câu trả lời của mô hình LLM đã cun...           8.00
# 3  Câu trả lời của mô hình LLM đã cung cấp một số...           6.00
# 4  Câu trả lời của mô hình LLM có nhiều điểm khôn...           2.67
# 5  Đánh giá tổng thể, câu trả lời của mô hình LLM...           5.67
# 6  Câu trả lời của mô hình LLM có nhiều điểm khôn...           4.33
# 7  Câu trả lời của mô hình LLM rất tốt, cung cấp ...           8.67
# 8  Câu trả lời của mô hình LLM đã cung cấp một số...           6.33
# 9  Câu trả lời của mô hình LLM nhìn chung đã đáp ...           8.33
#
#                                    Strength Weakness
# 0  Điểm mạnh:\n- Cung cấp thông tin chi tiết về c...
# 1  Điểm mạnh:\n- Cấu trúc câu trả lời rõ ràng, dễ...
# 2  Điểm mạnh:\n- Cấu trúc câu trả lời rõ ràng, dễ...
# 3  Điểm mạnh:\n- Câu trả lời ngắn gọn, dễ hiểu.\n...
# 4  Điểm mạnh: Câu trả lời có cấu trúc rõ ràng và ...
# 5  Điểm mạnh:\n1. Cố gắng cung cấp thông tin về c...
# 6  Điểm mạnh:\n- Câu trả lời ngắn gọn và dễ đọc.\...
# 7  Điểm mạnh:\n- Cung cấp hướng dẫn chính xác và ...
# 8  Điểm mạnh:\n- Đã nêu được yêu cầu bắt buộc về ...
# 9  Điểm mạnh:\n- Cung cấp câu trả lời chính xác v...

# %%
with pd.ExcelWriter("data/test/claude_sonnet_3_7.xlsx", engine="openpyxl") as writer:
    temp_df.to_excel(writer, sheet_name = "Prompt 1 Generator 0 Grader 0", header=True, index=False)

# %%
for index, comparison in enumerate(compare_claude_v2):
    compare = json.loads(comparison)
    generation = compare["generation"]
    sources_laws = compare["sources_laws"]
    brevity = compare["brevity"]
    generation_score = float(compare["generation_score"])
    sources_laws_score = float(compare["sources_laws_score"])
    brevity_score = float(compare["brevity_score"])
    comment = compare["comment"]
    strength_weakness = compare["strength_weakness"]

    score_df.loc[index, ("Generation", "Claude")] = str(generation_score) + "/10"
    score_df.loc[index, ("Sources - Laws", "Claude")] = str(sources_laws_score) + "/10"
    score_df.loc[index, ("Brevity", "Claude")] = str(brevity_score) + "/10"
    score_df.loc[index, ("Tổng điểm", "Claude")] = str(np.round((generation_score + sources_laws_score + brevity_score)/3, 2)) + "/10"
    comment_df.loc[index, "Câu trả lời sau rà soát"] = groundTruthAnswers[index]
    comment_df.loc[index, ("LLM anwser", "Claude")] = claude_answers[index]
    comment_df.loc[index, ("Đánh giá", "Claude")] = comment

# %% [markdown]
# ### Claude sonnet 3.5

# %%
claude_sonnet_3_5_answers = [] 
for question in questions:
    payload = {"question": question}
    temp = query(payload, CLAUDE_API)
    while True:
        data = langfuse.fetch_traces(limit=1).data[0]
        if current_id != data.id and (data.output is not None and not isinstance(data.output, str)):
            claude_sonnet_3_5_answers.append(data.output["tax_claude"]["messages"][0]["kwargs"]["content"])
            current_id = data.id
            print("Checkpoint: Claude")
            break
# Out:
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude
# Checkpoint: Claude

# %%
# Claude
compare_claude= []
for question, groundTruthAnswer, llmAnswer in zip(questions, groundTruthAnswers, claude_sonnet_3_5_answers):
    compare_question = f"""
    Question: {question}\n\n
    Ground-truth answer: {groundTruthAnswer}\n\n
    LLM answer: {llmAnswer}
    """
    payload = {"question": compare_question}
    temp = query(payload, GRADER_API)

    # Fetch the most recent trace
    traces = langfuse.fetch_traces(limit=1)
    while True:
        data = langfuse.fetch_traces(limit=1).data[0]
        if current_id != data.id and (data.output is not None and not isinstance(data.output, str)):
            compare_claude.append(data.output["tax_grader"]["messages"][0]["kwargs"]["content"])
            current_id = data.id
            print("Checkpoint: Comparison")
            break
# Out:
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison

# %%
average_score = 0
for compare in compare_claude:
    compare = json.loads(compare)
    generation_score = float(compare["generation_score"])
    sources_laws_score = float(compare["sources_laws_score"])
    brevity_score = float(compare["brevity_score"])
    average_score_per_cirtical = np.round((generation_score + sources_laws_score + brevity_score)/3, 2)
    average_score += average_score_per_cirtical
    print(generation_score, sources_laws_score, brevity_score, average_score_per_cirtical)
print(np.round(average_score/10, 2))
# Out:
# 1.0 0.0 0.0 0.33
# 3.0 2.0 3.0 2.67
# 1.0 0.0 1.0 0.67
# 1.0 0.0 2.0 1.0
# 2.0 1.0 3.0 2.0
# 2.0 1.0 3.0 2.0
# 2.0 3.0 3.0 2.67
# 1.0 2.0 3.0 2.0
# 1.0 0.0 2.0 1.0
# 0.0 0.0 2.0 0.67
# 1.5

# %%
compare_claude
# Out:
# ['{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Mô hình đã cung cấp thông tin về các mẫu biểu quyết toán thuế TNCN và đăng ký người phụ thuộc, trong khi câu hỏi yêu cầu hướng dẫn về cách tính thuế TNCN cho người lao động làm việc ngắn hạn và cách kê khai trong quyết toán thuế. Câu trả lời hoàn toàn không đề cập đến nội dung câu hỏi và không cung cấp thông tin hữu ích.","generation_score":"1","sources_laws":"Câu trả lời của mô hình không trích dẫn bất kỳ văn bản pháp luật nào liên quan đến câu hỏi. Trong khi đó, câu trả lời chuẩn đã trích dẫn chính xác Điểm b.2 Khoản 1 Điều 25 Thông tư 111/2013/TT-BTC, là văn bản pháp luật quan trọng để giải quyết vấn đề được hỏi.","sources_laws_score":"0","brevity":"Mặc dù câu trả lời của mô hình có độ dài vừa phải, nhưng nội dung hoàn toàn không liên quan đến câu hỏi. Vì vậy, không thể đánh giá tính ngắn gọn, súc tích của câu trả lời này.","brevity_score":"0","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Mô hình đã cung cấp thông tin về các mẫu biểu quyết toán thuế TNCN và đăng ký người phụ thuộc, trong khi câu hỏi yêu cầu hướng dẫn cụ thể về cách tính thuế TNCN cho người lao động làm việc ngắn hạn và cách kê khai trong quyết toán thuế. Câu trả lời không có giá trị sử dụng và có thể gây hiểu nhầm cho người đọc.","strength_weakness":"Điểm yếu:\\n1. Hoàn toàn không liên quan đến câu hỏi được đặt ra.\\n2. Không cung cấp bất kỳ thông tin hữu ích nào về cách tính thuế TNCN cho trường hợp cụ thể được hỏi.\\n3. Không trích dẫn văn bản pháp luật liên quan.\\n4. Có thể gây hiểu nhầm và làm mất thời gian của người đọc.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM chưa hoàn toàn chính xác và đầy đủ so với câu trả lời chuẩn. Mô hình đã đưa ra một số thông tin không liên quan đến câu hỏi như cách tính thuế TNCN và kê khai quyết toán thuế cuối năm, trong khi câu hỏi chỉ yêu cầu thông tin về mẫu biểu quyết toán thuế TNCN và mẫu đăng ký người phụ thuộc. Mô hình không cung cấp đầy đủ các mẫu biểu theo yêu cầu và không trích dẫn chính xác các văn bản pháp luật liên quan.","generation_score":"3","sources_laws":"Câu trả lời của mô hình LLM không trích dẫn chính xác và đầy đủ các văn bản pháp luật liên quan như trong câu trả lời chuẩn. Mô hình chỉ đề cập đến Thông tư 111/2013/TT-BTC và Thông tư 92/2015/TT-BTC, trong khi câu trả lời chuẩn trích dẫn Nghị định số 126/2020/NĐ-CP và Thông tư số 80/2021/TT-BTC. Việc thiếu trích dẫn chính xác các văn bản pháp luật mới nhất ảnh hưởng nghiêm trọng đến độ tin cậy của câu trả lời.","sources_laws_score":"2","brevity":"Câu trả lời của mô hình LLM không ngắn gọn và súc tích. Mô hình đưa ra nhiều thông tin không liên quan đến câu hỏi, làm cho câu trả lời trở nên dài dòng và khó theo dõi. Câu trả lời cần tập trung vào việc liệt kê các mẫu biểu quyết toán thuế TNCN và mẫu đăng ký người phụ thuộc như trong câu trả lời chuẩn.","brevity_score":"3","comment":"Câu trả lời của mô hình LLM không đáp ứng yêu cầu của câu hỏi và có nhiều thiếu sót so với câu trả lời chuẩn. Mô hình đưa ra thông tin không liên quan, không trích dẫn chính xác văn bản pháp luật, và không cung cấp đầy đủ các mẫu biểu theo yêu cầu. Câu trả lời cần được cải thiện đáng kể để đảm bảo tính chính xác, đầy đủ và phù hợp với câu hỏi.","strength_weakness":"Điểm yếu: \\n1. Không trả lời đúng trọng tâm câu hỏi về mẫu biểu quyết toán thuế TNCN và mẫu đăng ký người phụ thuộc.\\n2. Đưa ra thông tin không liên quan và không cần thiết.\\n3. Không trích dẫn chính xác và đầy đủ các văn bản pháp luật mới nhất.\\n4. Thiếu các mẫu biểu cụ thể theo yêu cầu của câu hỏi.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Mô hình đã cung cấp thông tin về mẫu biểu quyết toán thuế TNCN và đăng ký người phụ thuộc, trong khi câu hỏi thực tế liên quan đến việc kê khai thuế TNCN cho cá nhân trúng thưởng từ chương trình marketing. Câu trả lời hoàn toàn không đề cập đến các vấn đề được nêu trong câu hỏi.","generation_score":"1","sources_laws":"Câu trả lời của mô hình không trích dẫn bất kỳ văn bản pháp luật nào liên quan đến câu hỏi. Trong khi đó, câu trả lời chuẩn đã trích dẫn các văn bản pháp luật quan trọng như Thông tư số 80/2021/TT-BTC và Nghị định số 122/2017/NĐ-CP.","sources_laws_score":"0","brevity":"Mặc dù câu trả lời của mô hình khá ngắn gọn, nhưng nó hoàn toàn không liên quan đến câu hỏi được đặt ra. Do đó, mức độ ngắn gọn và súc tích không thể được đánh giá một cách có ý nghĩa trong trường hợp này.","brevity_score":"1","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Mô hình đã cung cấp thông tin không liên quan về mẫu biểu quyết toán thuế TNCN và đăng ký người phụ thuộc, trong khi câu hỏi thực tế liên quan đến việc kê khai thuế TNCN cho cá nhân trúng thưởng từ chương trình marketing. Câu trả lời không đề cập đến bất kỳ vấn đề nào được nêu trong câu hỏi, không trích dẫn văn bản pháp luật liên quan, và không cung cấp hướng dẫn cụ thể cho người hỏi.","strength_weakness":"Điểm yếu:\\n1. Hoàn toàn không liên quan đến câu hỏi được đặt ra.\\n2. Không cung cấp thông tin hữu ích hoặc chính xác cho người hỏi.\\n3. Không trích dẫn văn bản pháp luật liên quan.\\n4. Không giải quyết các vấn đề cụ thể được nêu trong câu hỏi.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Câu hỏi yêu cầu hướng dẫn về việc kê khai biểu 05-1 hay 05-2 cho trường hợp người lao động vừa có thời gian thử việc khấu trừ thuế TNCN 10% và có thời gian lao động chính thức khấu trừ thuế TNCN theo biểu lũy tiến từng phần. Tuy nhiên, câu trả lời của mô hình lại đề cập đến việc kê khai tờ khai 06/TNCN cho thu nhập từ trúng thưởng, điều này hoàn toàn không liên quan đến câu hỏi.","generation_score":"1","sources_laws":"Câu trả lời của mô hình không trích dẫn bất kỳ văn bản pháp luật nào liên quan đến câu hỏi. Trong khi đó, câu trả lời chuẩn đã trích dẫn chính xác Điều 25 Thông tư số 111/2013/TT-BTC về quy định khấu trừ thuế, điều này rất quan trọng để giải thích cách xử lý tình huống được hỏi.","sources_laws_score":"0","brevity":"Mặc dù câu trả lời của mô hình có độ dài vừa phải, nhưng nội dung hoàn toàn không liên quan đến câu hỏi. Câu trả lời đưa ra thông tin về kê khai thuế thu nhập từ trúng thưởng, trong khi câu hỏi liên quan đến kê khai thuế thu nhập cá nhân cho người lao động có cả thời gian thử việc và thời gian làm việc chính thức.","brevity_score":"2","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Mô hình đã hiểu sai hoàn toàn nội dung câu hỏi và đưa ra câu trả lời về một vấn đề khác (kê khai thuế thu nhập từ trúng thưởng) thay vì vấn đề được hỏi (kê khai thuế thu nhập cá nhân cho người lao động có cả thời gian thử việc và thời gian làm việc chính thức). Câu trả lời không có giá trị sử dụng và có thể gây hiểu nhầm cho người đọc.","strength_weakness":"Điểm yếu:\\n1. Hoàn toàn không hiểu và trả lời đúng câu hỏi được đặt ra.\\n2. Không trích dẫn văn bản pháp luật liên quan.\\n3. Đưa ra thông tin không liên quan và có thể gây hiểu nhầm.\\n4. Thiếu sự chính xác và độ tin cậy trong việc cung cấp thông tin về thuế.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không đáp ứng được yêu cầu của câu hỏi. Mô hình đã đưa ra thông tin không liên quan về thuế suất áp dụng cho thời gian thử việc và làm việc chính thức, trong khi câu hỏi chỉ yêu cầu hướng dẫn cách kê khai chỉ tiêu [12] và [13] trên mẫu 05-1/BK-QTT-TNCN cho trường hợp cá nhân được điều chuyển từ tổ chức cũ sang tổ chức mới trong cùng hệ thống.","generation_score":"2","sources_laws":"Câu trả lời của mô hình không trích dẫn bất kỳ văn bản pháp luật nào liên quan đến việc kê khai chỉ tiêu [12] và [13] trên mẫu 05-1/BK-QTT-TNCN. Thay vào đó, mô hình đã trích dẫn không chính xác Thông tư 111/2013/TT-BTC về thuế suất áp dụng cho thời gian thử việc và làm việc chính thức, điều này hoàn toàn không liên quan đến câu hỏi.","sources_laws_score":"1","brevity":"Câu trả lời của mô hình quá dài và chứa nhiều thông tin không liên quan. Mô hình đã đưa ra thông tin về thuế suất áp dụng cho thời gian thử việc và làm việc chính thức, cách phân biệt Phụ lục 05-1/BK-TNCN và 05-2/BK-TNCN, trong khi câu hỏi chỉ yêu cầu hướng dẫn cụ thể về cách kê khai hai chỉ tiêu [12] và [13].","brevity_score":"3","comment":"Câu trả lời của mô hình LLM không đáp ứng được yêu cầu của câu hỏi và chứa nhiều thông tin không liên quan. Mô hình đã không cung cấp hướng dẫn cụ thể về cách kê khai chỉ tiêu [12] và [13] trên mẫu 05-1/BK-QTT-TNCN cho trường hợp cá nhân được điều chuyển từ tổ chức cũ sang tổ chức mới trong cùng hệ thống. Thay vào đó, mô hình đã đưa ra thông tin về thuế suất áp dụng cho thời gian thử việc và làm việc chính thức, cũng như cách phân biệt các loại phụ lục kê khai, điều này hoàn toàn không liên quan đến câu hỏi. Câu trả lời cũng không trích dẫn bất kỳ văn bản pháp luật nào liên quan đến việc kê khai các chỉ tiêu này.","strength_weakness":"Điểm yếu: \\n1. Không trả lời đúng câu hỏi được đặt ra.\\n2. Đưa ra thông tin không liên quan và không cần thiết.\\n3. Không trích dẫn văn bản pháp luật liên quan đến việc kê khai chỉ tiêu [12] và [13].\\n4. Câu trả lời quá dài và lan man.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Câu hỏi yêu cầu hướng dẫn về việc khai báo thuế cho cá nhân có cả thu nhập tính thuế theo biểu thuế lũy tiến và thuế suất 10%, nhưng câu trả lời lại đề cập đến việc kê khai cho người lao động được điều chuyển giữa các tổ chức. Nội dung này hoàn toàn không liên quan đến câu hỏi ban đầu.","generation_score":"2","sources_laws":"Mô hình LLM đã trích dẫn Thông tư số 80/2021/TT-BTC, tuy nhiên việc trích dẫn này không phù hợp với câu hỏi và câu trả lời chuẩn. Câu trả lời chuẩn đã chính xác trích dẫn Nghị định 126/2020/NĐ-CP, điểm d Khoản 6 Điều 8, nhưng mô hình LLM không đề cập đến nguồn này.","sources_laws_score":"1","brevity":"Câu trả lời của mô hình LLM khá dài dòng và không súc tích. Nó cung cấp nhiều thông tin không liên quan đến câu hỏi, trong khi lại thiếu các thông tin cần thiết để trả lời câu hỏi ban đầu.","brevity_score":"3","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Nó đưa ra thông tin không liên quan về cách kê khai cho người lao động được điều chuyển giữa các tổ chức, trong khi câu hỏi yêu cầu hướng dẫn về việc khai báo thuế cho cá nhân có cả thu nhập tính thuế theo biểu thuế lũy tiến và thuế suất 10%. Mô hình đã không nắm bắt được yêu cầu chính của câu hỏi, dẫn đến việc cung cấp thông tin sai lệch và không phù hợp. Việc trích dẫn nguồn luật cũng không chính xác, và cách trình bày không súc tích, gây khó khăn cho người đọc trong việc tìm kiếm thông tin cần thiết.","strength_weakness":"Điểm yếu: \\n1. Hoàn toàn không nắm bắt được nội dung câu hỏi, dẫn đến câu trả lời sai lệch và không liên quan.\\n2. Trích dẫn nguồn luật không phù hợp với câu hỏi.\\n3. Cung cấp thông tin dư thừa và không cần thiết.\\n4. Thiếu các thông tin quan trọng để trả lời câu hỏi ban đầu.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan trực tiếp đến câu hỏi được đặt ra. Câu hỏi yêu cầu thông tin về việc điền số thuế TNCN đã khấu trừ trùng do quyết toán vắt năm vào chỉ tiêu nào (37 hay 38) trên mẫu 02/QTT-TNCN, nhưng câu trả lời của mô hình lại đề cập đến cách khai quyết toán thuế TNCN cho các loại thu nhập khác nhau, không đề cập đến chỉ tiêu cụ thể như yêu cầu.","generation_score":"2","sources_laws":"Câu trả lời của mô hình có đề cập đến Thông tư số 80/2021/TT-BTC ngày 29/09/2021 của Bộ Tài chính, nhưng không trích dẫn cụ thể các điều khoản liên quan đến việc kê khai số thuế TNCN đã khấu trừ trùng do quyết toán vắt năm. Trong khi đó, câu trả lời chuẩn đã chỉ rõ thông tin này được kê khai tại chỉ tiêu [37] trên mẫu 02/QTT-TNCN theo Thông tư 80/2021/TT-BTC.","sources_laws_score":"3","brevity":"Câu trả lời của mô hình khá dài dòng và không tập trung vào vấn đề chính của câu hỏi. Thay vì trả lời ngắn gọn về chỉ tiêu cần điền thông tin, mô hình lại đưa ra thông tin không liên quan về cách khai quyết toán cho các loại thu nhập khác nhau.","brevity_score":"3","comment":"Câu trả lời của mô hình LLM không đáp ứng được yêu cầu của câu hỏi. Mô hình đã không hiểu đúng trọng tâm của câu hỏi và đưa ra thông tin không liên quan. Câu trả lời thiếu chính xác, không trích dẫn đúng nguồn luật pháp cần thiết, và không ngắn gọn, súc tích. Cần cải thiện đáng kể về khả năng hiểu câu hỏi và cung cấp thông tin chính xác, liên quan.","strength_weakness":"Điểm yếu: \\n1. Không hiểu đúng trọng tâm của câu hỏi.\\n2. Cung cấp thông tin không liên quan và không chính xác.\\n3. Không trích dẫn đúng và đầy đủ nguồn luật pháp liên quan.\\n4. Câu trả lời dài dòng và không tập trung vào vấn đề chính.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Mô hình đã đưa ra thông tin về quyết toán vắt năm và cách điền các chỉ tiêu 37, 38 trên mẫu 02/QTT-TNCN, trong khi câu hỏi thực tế là về lỗi kê khai giảm trừ phụ thuộc trên mẫu 05-1/BK-TNCN. Câu trả lời hoàn toàn không đề cập đến vấn đề cần giải quyết.","generation_score":"1","sources_laws":"Mô hình có trích dẫn Thông tư số 80/2021/TT-BTC ngày 29/09/2021 của Bộ Tài chính, nhưng việc trích dẫn này không liên quan đến câu hỏi và không giúp giải quyết vấn đề của người hỏi. Không có trích dẫn nào liên quan đến mẫu 05-1/BK-TNCN hay vấn đề kê khai giảm trừ phụ thuộc.","sources_laws_score":"2","brevity":"Mặc dù câu trả lời của mô hình có độ dài vừa phải, nhưng nội dung hoàn toàn không liên quan đến câu hỏi. Câu trả lời lan man về các chỉ tiêu không liên quan (37, 38) và quyết toán vắt năm, trong khi không đề cập gì đến vấn đề cần giải quyết.","brevity_score":"3","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Mô hình đã đưa ra thông tin không liên quan về quyết toán vắt năm và cách điền các chỉ tiêu 37, 38 trên mẫu 02/QTT-TNCN, trong khi câu hỏi thực tế là về lỗi kê khai giảm trừ phụ thuộc trên mẫu 05-1/BK-TNCN. Câu trả lời không giải quyết vấn đề của người hỏi và có thể gây nhầm lẫn. Mô hình cần cải thiện đáng kể khả năng hiểu và trả lời đúng trọng tâm câu hỏi.","strength_weakness":"Điểm yếu:\\n1. Hoàn toàn không hiểu và trả lời đúng câu hỏi.\\n2. Đưa ra thông tin không liên quan và có thể gây nhầm lẫn.\\n3. Trích dẫn luật không phù hợp với nội dung câu hỏi.\\n4. Không cung cấp hướng dẫn cụ thể để giải quyết vấn đề của người hỏi.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Mô hình đã đưa ra hướng dẫn về cách khắc phục lỗi kê khai bảng kê 05-1/BK-TNCN, trong khi câu hỏi thực tế là về việc có bắt buộc phải điền mã số thuế cá nhân của người lao động vào mẫu 5-1BK-TNCN hay không và tính hợp lệ của chi phí lương nếu không điền mã số thuế.","generation_score":"1","sources_laws":"Câu trả lời của mô hình không trích dẫn bất kỳ văn bản pháp luật nào, trong khi câu trả lời chuẩn đã đề cập đến Luật Quản lý Thuế số 38/2019/QH14 ngày 13 tháng 6 năm 2019 của Quốc hội.","sources_laws_score":"0","brevity":"Câu trả lời của mô hình dài dòng và không liên quan đến câu hỏi. Nó cung cấp thông tin về cách khắc phục lỗi kê khai bảng kê, trong khi câu hỏi yêu cầu thông tin về việc điền mã số thuế cá nhân.","brevity_score":"2","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Mô hình đã đưa ra thông tin không liên quan về cách khắc phục lỗi kê khai bảng kê thay vì trả lời về việc điền mã số thuế cá nhân và tính hợp lệ của chi phí lương. Câu trả lời không có bất kỳ trích dẫn pháp luật nào và cũng không ngắn gọn, súc tích. Cần phải cải thiện đáng kể về khả năng hiểu và trả lời đúng câu hỏi, cũng như việc trích dẫn các văn bản pháp luật liên quan.","strength_weakness":"Điểm yếu: \\n1. Hoàn toàn không hiểu và trả lời đúng câu hỏi.\\n2. Không có trích dẫn văn bản pháp luật liên quan.\\n3. Cung cấp thông tin không liên quan và dài dòng.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}',
#  '{"generation":"Câu trả lời của mô hình LLM không chính xác và không liên quan đến câu hỏi được đặt ra. Câu hỏi yêu cầu thông tin về nơi quyết toán thuế TNCN trong trường hợp người lao động chuyển nơi làm việc, nhưng câu trả lời lại đề cập đến việc điền mã số thuế cá nhân và tính hợp lệ của chi phí lương. Câu trả lời hoàn toàn không đúng với nội dung câu hỏi và câu trả lời chuẩn.","generation_score":"0","sources_laws":"Câu trả lời của mô hình LLM không trích dẫn đúng văn bản pháp luật liên quan đến câu hỏi. Mô hình đề cập đến Thông tư số 80/2021/TT-BTC, Thông tư 96/2015/TT-BTC và Thông tư 25/2018/TT-BTC, trong khi câu trả lời chuẩn trích dẫn chính xác Nghị định số 126/2020/NĐ-CP của Chính phủ. Các văn bản được trích dẫn trong câu trả lời của mô hình không liên quan đến vấn đề quyết toán thuế TNCN khi chuyển nơi làm việc.","sources_laws_score":"0","brevity":"Câu trả lời của mô hình LLM quá dài và không súc tích. Nó cung cấp nhiều thông tin không liên quan đến câu hỏi, như việc điền mã số thuế và tính hợp lệ của chi phí lương. Câu trả lời chuẩn ngắn gọn và đi thẳng vào vấn đề, trong khi câu trả lời của mô hình lan man và không đúng trọng tâm.","brevity_score":"2","comment":"Câu trả lời của mô hình LLM hoàn toàn không đáp ứng yêu cầu của câu hỏi. Nó cung cấp thông tin không liên quan, không trích dẫn đúng văn bản pháp luật, và không giải quyết vấn đề mà người hỏi đang quan tâm. Câu trả lời cần được cải thiện toàn diện về nội dung, độ chính xác, và sự phù hợp với câu hỏi.","strength_weakness":"Điểm yếu:\\n1. Hoàn toàn không đúng với nội dung câu hỏi.\\n2. Không trích dẫn đúng văn bản pháp luật liên quan.\\n3. Cung cấp thông tin không liên quan và không hữu ích.\\n4. Quá dài dòng và không súc tích.\\n\\nĐiểm mạnh: Không có điểm mạnh đáng kể trong câu trả lời này."}']

# %%
# Llama
compare_llama_v2 = []
for question, groundTruthAnswer, llmAnswer in zip(questions, groundTruthAnswers, llama_answers):
    compare_question = f"""
    Question: {question}\n\n
    Ground-truth answer: {groundTruthAnswer}\n\n
    LLM answer: {llmAnswer}
    """
    payload = {"question": compare_question}
    temp = query(payload, GRADER_API)

    # Fetch the most recent trace
    traces = langfuse.fetch_traces(limit=1)
    while True:
        data = langfuse.fetch_traces(limit=1).data[0]
        if current_id != data.id and (data.output is not None and not isinstance(data.output, str)):
            compare_llama_v2.append(data.output["tax_grader"]["messages"][0]["kwargs"]["content"])
            current_id = data.id
            print("Checkpoint: Comparison")
            break
# Out:
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison

# %%
for index, comparison in enumerate(compare_llama_v2):
    compare = json.loads(comparison)
    generation = compare["generation"]
    sources_laws = compare["sources_laws"]
    brevity = compare["brevity"]
    generation_score = float(compare["generation_score"])
    sources_laws_score = float(compare["sources_laws_score"])
    brevity_score = float(compare["brevity_score"])
    comment = compare["comment"]
    strength_weakness = compare["strength_weakness"]

    comparisons_score.loc[index, ("Generation", "Llama")] = str(generation_score) + "/10"
    comparisons_score.loc[index, ("Sources - Laws", "Llama")] = str(sources_laws_score) + "/10"
    comparisons_score.loc[index, ("Brevity", "Llama")] = str(brevity_score) + "/10"
    comparisons_score.loc[index, ("Tổng điểm", "Llama")] = str(np.round((generation_score + sources_laws_score + brevity_score)/3, 2)) + "/10"
    comparisons_comment.loc[index, "Câu trả lời sau rà soát"] = groundTruthAnswers[index]
    comparisons_comment.loc[index, ("LLM anwser", "Llama")] = llama_answers[index]
    comparisons_comment.loc[index, ("Đánh giá", "Llama")] = comment

# %%
cucthue_chatbot_df = pd.read_csv("data/cucthue_chatbot_answer.csv")
cucthue_chatbot_answers = cucthue_chatbot_df["cucthue_chatbot"].values

# %%
# Cucthue chatbot
compare_cucthue_chatbot = []
for question, groundTruthAnswer, llmAnswer in zip(questions, groundTruthAnswers, cucthue_chatbot_answers):
    compare_question = f"""
    Question: {question}\n\n
    Ground-truth answer: {groundTruthAnswer}\n\n
    LLM answer: {llmAnswer}
    """
    payload = {"question": compare_question}
    temp = query(payload, GRADER_API)

    # Fetch the most recent trace
    traces = langfuse.fetch_traces(limit=1)
    while True:
        data = langfuse.fetch_traces(limit=1).data[0]
        if current_id != data.id and (data.output is not None and not isinstance(data.output, str)):
            compare_cucthue_chatbot.append(data.output["tax_grader"]["messages"][0]["kwargs"]["content"])
            current_id = data.id
            print("Checkpoint: Comparison")
            break
# Out:
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison
# Checkpoint: Comparison

# %%
for index, comparison in enumerate(compare_cucthue_chatbot):
    compare = json.loads(comparison)
    generation = compare["generation"]
    sources_laws = compare["sources_laws"]
    brevity = compare["brevity"]
    generation_score = float(compare["generation_score"])
    sources_laws_score = float(compare["sources_laws_score"])
    brevity_score = float(compare["brevity_score"])
    comment = compare["comment"]
    strength_weakness = compare["strength_weakness"]

    comparisons_score.loc[index, ("Generation", "Chatbot cục thuế")] = str(generation_score) + "/10"
    comparisons_score.loc[index, ("Sources - Laws", "Chatbot cục thuế")] = str(sources_laws_score) + "/10"
    comparisons_score.loc[index, ("Brevity", "Chatbot cục thuế")] = str(brevity_score) + "/10"
    comparisons_score.loc[index, ("Tổng điểm", "Chatbot cục thuế")] = str(np.round((generation_score + sources_laws_score + brevity_score)/3, 2)) + "/10"
    comparisons_comment.loc[index, "Câu trả lời sau rà soát"] = groundTruthAnswers[index]
    comparisons_comment.loc[index, ("LLM anwser", "Chatbot cục thuế")] = cucthue_chatbot_answers[index]
    comparisons_comment.loc[index, ("Đánh giá", "Chatbot cục thuế")] = comment
# Out:
# /tmp/ipykernel_336966/963092113.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.0/10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comparisons_score.loc[index, ("Generation", "Chatbot cục thuế")] = str(generation_score) + "/10"
# /tmp/ipykernel_336966/963092113.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.0/10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comparisons_score.loc[index, ("Sources - Laws", "Chatbot cục thuế")] = str(sources_laws_score) + "/10"
# /tmp/ipykernel_336966/963092113.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.0/10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comparisons_score.loc[index, ("Brevity", "Chatbot cục thuế")] = str(brevity_score) + "/10"
# /tmp/ipykernel_336966/963092113.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.0/10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comparisons_score.loc[index, ("Tổng điểm", "Chatbot cục thuế")] = str(np.round((generation_score + sources_laws_score + brevity_score)/3, 2)) + "/10"
# /tmp/ipykernel_336966/963092113.py:17: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Dựa trên thông tin bạn cung cấp, tôi xin hướng dẫn cách tính thuế TNCN và kê khai quyết toán thuế như sau:
#
#
#     Căn cứ pháp lý: Theo quy định hiện hành tại Điều 25 Thông tư số 111/2013/TT-BTC của Bộ Tài chính, bạn có thể tham khảo nội dung được hướng dẫn sau đây:
#
#     Đối với người lao động ký hợp đồng lao động không thời hạn hoặc hợp đồng có thời hạn từ 3 tháng trở lên, doanh nghiệp cần tính thuế TNCN theo Biểu thuế lũy tiến từng phần, không phân biệt thời gian làm việc thực tế.
#
#     Khi quyết toán thuế cuối năm:
#         Nếu người lao động ủy quyền cho doanh nghiệp quyết toán thay: Doanh nghiệp kê khai vào Phụ lục Bảng kê 05-1/BK-QTT-TNCN.
#         Nếu người lao động không ủy quyền quyết toán: Doanh nghiệp kê khai vào Phụ lục Bảng kê 05-2/BK-QTT-TNCN.
#
#     Lưu ý: Doanh nghiệp cần tổng hợp toàn bộ thu nhập và số thuế đã khấu trừ của cá nhân trong thời gian làm việc, bất kể thời gian làm việc thực tế là bao lâu.
#
#     Câu trả lời chỉ mang tính tham khảo, trong quá trình thực hiện, trường hợp còn vướng mắc, quý vị vui lòng tham khảo các văn bản hướng dẫn được đăng tải trên website của cơ quan thuế hoặc liên hệ với cơ quan thuế quản lý trực tiếp để được hỗ trợ giải quyết. Trân trọng cảm ơn!
#
# ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comparisons_comment.loc[index, ("LLM anwser", "Chatbot cục thuế")] = cucthue_chatbot_answers[index]
# /tmp/ipykernel_336966/963092113.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Câu trả lời của mô hình LLM có độ chính xác tương đối tốt về nội dung chính, nhưng còn một số điểm cần cải thiện. Mô hình đã đúng khi nêu cách tính thuế TNCN theo Biểu thuế lũy tiến từng phần và trích dẫn đúng nguồn luật. Tuy nhiên, câu trả lời còn dài dòng và bổ sung thêm thông tin không cần thiết về ủy quyền quyết toán, điều này có thể gây nhầm lẫn cho người đọc. Mô hình cần tập trung hơn vào việc trả lời đúng trọng tâm câu hỏi và giữ câu trả lời ngắn gọn, súc tích hơn.' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comparisons_comment.loc[index, ("Đánh giá", "Chatbot cục thuế")] = comment

# %%
with pd.ExcelWriter("data/comparisons.xlsx", engine="openpyxl") as writer:
    comparisons_score.to_excel(writer, sheet_name="Điểm")
    comparisons_comment.to_excel(writer, sheet_name="Đánh giá")

# %%
comparisons_score
# Out:
#                              Tiêu chí\n\n\n\nCâu hỏi Generation          \
#                                   Unnamed: 0_level_1     Claude   Llama
# 0  Người lao động ký hợp đồng lao động không thời...     6.0/10  6.0/10
# 1  Mẫu biểu quyết toán thuế TNCN của cty là mẫu n...     5.0/10  6.0/10
# 2  "Bên em có trường hợp xuất Chứng từ khấu trừ t...     7.0/10  5.0/10
# 3  NLĐ vừa có thời gian thử việc khấu trừ thuế TN...     7.0/10  3.0/10
# 4  Quyết toán thuế TNCN đối với cá nhân được điều...     6.0/10  5.0/10
# 5  Cá nhân trong năm vừa có thu nhập tính thuế th...     3.0/10  7.0/10
# 6  Mẫu số 02/QTT-TNCN/ TT80, trong trường hợp quy...     4.0/10  3.0/10
# 7  Tôi đang kê khai quyết toán thuế nhưng phần kê...     9.0/10  9.5/10
# 8  A/C cho e hỏi có bắt buộc phải điền mã số thuế...     8.0/10  6.0/10
# 9  Trong năm 2023 tôi có làm việc tại Nha Trang, ...     6.0/10  5.0/10
#
#                    Sources - Laws                          Brevity          \
#   Chatbot cục thuế         Claude   Llama Chatbot cục thuế  Claude   Llama
# 0           8.0/10         5.0/10  5.0/10           7.0/10  6.0/10  5.0/10
# 1           7.0/10         4.0/10  1.0/10           6.0/10  6.0/10  6.0/10
# 2           6.0/10         6.0/10  4.0/10           5.0/10  7.0/10  6.0/10
# 3           8.0/10         6.0/10  2.0/10           7.0/10  8.0/10  5.0/10
# 4           5.0/10         5.0/10  4.0/10           3.0/10  4.0/10  2.0/10
# 5           3.0/10         2.0/10  6.0/10           2.0/10  4.0/10  8.0/10
# 6           3.0/10         6.0/10  2.0/10           1.0/10  6.0/10  4.0/10
# 7           6.0/10         7.0/10  8.0/10           8.0/10  8.0/10  9.0/10
# 8           5.0/10         7.0/10  4.0/10           3.0/10  6.0/10  5.0/10
# 9           9.0/10         7.0/10  6.0/10           9.0/10  4.0/10  4.0/10
#
#                    Tổng điểm
#   Chatbot cục thuế    Claude    Llama Chatbot cục thuế
# 0           6.0/10   5.67/10  5.33/10           7.0/10
# 1           7.0/10    5.0/10  4.33/10          6.67/10
# 2           7.0/10   6.67/10   5.0/10           6.0/10
# 3           8.0/10    7.0/10  3.33/10          7.67/10
# 4           2.0/10    5.0/10  3.67/10          3.33/10
# 5           4.0/10    3.0/10   7.0/10           3.0/10
# 6           4.0/10   5.33/10   3.0/10          2.67/10
# 7           5.0/10    8.0/10  8.83/10          6.33/10
# 8           4.0/10    7.0/10   5.0/10           4.0/10
# 9           7.0/10   5.67/10   5.0/10          8.33/10

# %%
with pd.ExcelWriter("data/comparisons.xlsx", engine="openpyxl") as writer:
    score_df.to_excel(writer, sheet_name="Điểm")
    comment_df.to_excel(writer, sheet_name="Đánh giá")

# %%
data = {'generation': {},
        'generation_score': {},
        'sources_laws': {},
        'sources_laws_score': {},
        'brevity': {},
        'brevity_score': {},
        'comment': {},
        'strength_weakness': {},
        'average_score': {}}
for index, compare in enumerate(compare_claude_v2):
    compare = json.loads(compare)
    
    data['generation'].update({index: compare['generation']})
    data['generation_score'].update({index:float(compare['generation_score'])})
    data['sources_laws'].update({index: compare['sources_laws']})
    data['sources_laws_score'].update({index: float(compare['sources_laws_score'])})
    data['brevity'].update({index: compare['brevity']})
    data['brevity_score'].update({index: float(compare['brevity_score'])})
    data['comment'].update({index: compare['comment']})
    data['strength_weakness'].update({index: compare['strength_weakness']})
    data['average_score'].update({index: np.round((float(compare['generation_score']) + float(compare['sources_laws_score']) + float(compare['brevity_score'])) / 3, 2)})

# %%
score_df_data = score_df.to_dict()
comment_df_data = comment_df.to_dict()

# %%
answers = {i: answer for i, answer in enumerate(claude_sonnet_3_7_answers)}
new_score_df_data, new_comment_df_data = insert_subcol(score_df_data=score_df_data,
              comment_df_data=comment_df_data,
              subcol="Claude 3.7",
              answers=answers,
              data=data)

# %%
new_score_df = pd.DataFrame(new_score_df_data)
new_comment_df = pd.DataFrame(new_comment_df_data)

# %%
with pd.ExcelWriter("data/comparisons.xlsx", engine="openpyxl") as writer:
    new_score_df.to_excel(writer, sheet_name="Điểm")
    new_comment_df.to_excel(writer, sheet_name="Đánh giá")
